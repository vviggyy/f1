# %%
# !pip install plotly[express]
# Out:
# Requirement already satisfied: plotly[express] in /home/idies/miniconda3/lib/python3.8/site-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in /home/idies/miniconda3/lib/python3.8/site-packages (from plotly[express]) (1.36.0)
# Requirement already satisfied: packaging in /home/idies/miniconda3/lib/python3.8/site-packages (from plotly[express]) (20.8)
# Collecting numpy
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/idies/miniconda3/lib/python3.8/site-packages (from packaging->plotly[express]) (2.4.7)
# Installing collected packages: numpy
# Successfully installed numpy-1.24.4

# %%
#import plotly.express as px
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import interact

# %%
wide = pd.read_csv("pos_yas_marina_2016_placeOF_multi_0.csv", index_col = 0)

# %%
# %matplotlib notebook
# Out:
# Warning: Cannot change to a different GUI toolkit: notebook. Using widget instead.
# ModuleNotFoundErrorTraceback (most recent call last)
# <ipython-input-37-7a6b33cdc204> in <module>
# ----> 1 get_ipython().run_line_magic('matplotlib', 'notebook')
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-101> in matplotlib(self, line)
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      97             print("Available matplotlib backends: %s" % backends_list)
#      98         else:
# ---> 99             gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100             self._show_matplotlib_backend(args.gui, backend)
#     101
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    3504                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    3505
# -> 3506         pt.activate_matplotlib(backend)
#    3507         pt.configure_inline_support(self, backend)
#    3508
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     320     from matplotlib import pyplot as plt
#     321
# --> 322     plt.switch_backend(backend)
#     323
#     324     plt.show._needmain = False
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     219         else "matplotlib.backends.backend_{}".format(newbackend.lower()))
#     220
# --> 221     backend_mod = importlib.import_module(backend_name)
#     222     Backend = type(
#     223         "Backend", (matplotlib.backends._Backend,), vars(backend_mod))
#
# ~/miniconda3/envs/py38/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/miniconda3/envs/py38/lib/python3.8/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/miniconda3/envs/py38/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/miniconda3/envs/py38/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/miniconda3/envs/py38/lib/python3.8/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/miniconda3/envs/py38/lib/python3.8/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/miniconda3/envs/py38/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/miniconda3/envs/py38/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'ipympl'

# %%
wide
# Out:
#      lap1  lap2  lap3  lap4  lap5  lap6  lap7  lap8  lap9  lap10  ...  lap47  \
# VAN    18    19    17    17    17    17    17    16    16     17  ...     15
# RIC     5     5     4     4     4     4     4     4     2      2  ...      5
# VET     3     2    18    19    19    19    18    17    17     13  ...      3
# RAI     4     7     6     6     6     6     6    19    19     19  ...     19
# GRO     7     8     7     7     7     7     7     6    15     15  ...      6
# ERI    12    11     9     9     9     9     9     8     6      6  ...     18
# GAS    17    16    14    14    14    14    14    13    12     12  ...     16
# PER    14    17    15    15    15    15    15    14    13     14  ...     14
# ALO    15    14    12    12    12    12    12    11     9      9  ...     11
# LEC     8     4     3     3     3     3     3     3    10     10  ...      4
# STR    20    18    16    16    16    16    16    15    14     16  ...     13
# MAG    13    13    11    11    11    11    11    10     8      8  ...      9
# HUL    10    20    20    20    20    20    20    20    20     20  ...     20
# HAR    16     9    19    18    18    18    19    18    18     18  ...     12
# OCO     9    10     8     8     8     8     8     7     5      5  ...     17
# VER     6     3     2     2     2     2     2     2     1      1  ...      2
# SIR    19    15    13    13    13    13    13    12    11     11  ...     10
# HAM     1     1     1     1     1     1     1     1     4      4  ...      1
# SAI    11    12    10    10    10    10    10     9     7      7  ...      8
# BOT     2     6     5     5     5     5     5     5     3      3  ...      7
#
#      lap48  lap49  lap50  lap51  lap52  lap53  lap54  lap55  lap56
# VAN     15     15     15     15     15     15     15     15     15
# RIC      5      5      5      5      5      5      5      5      5
# VET      3      3      3      3      3      3      3      3      3
# RAI     19     19     19     19     19     19     19     19     19
# GRO      6      6      6      6      6      6      6      6      6
# ERI     18     18     18     18     18     18     18     18     18
# GAS     16     16     16     16     16     16     16     16     16
# PER     14     14     14     14     14     14     14     14     14
# ALO     11     11     11     11     11     11     11     11     11
# LEC      4      4      4      4      4      4      4      4      4
# STR     13     13     13     13     13     13     13     13     13
# MAG      9      9      9      9      9      9      9      9      9
# HUL     20     20     20     20     20     20     20     20     20
# HAR     12     12     12     12     12     12     12     12     12
# OCO     17     17     17     17     17     17     17     17     17
# VER      2      2      2      2      2      2      2      2      2
# SIR     10     10     10     10     10     10     10     10     10
# HAM      1      1      1      1      1      1      1      1      1
# SAI      8      8      8      8      8      8      8      8      8
# BOT      7      7      7      7      7      7      7      7      7
#
# [20 rows x 56 columns]

# %%
# 2) prepare a helper to grab “driver slots”
drivers = list(wide.index)
slot = {d: i for i, d in enumerate(drivers, start=1)}


# 3) plotting function
def plot_lap(lap: int):
    plt.figure(figsize=(10, 6))
    pos = wide[f"lap{lap}"]
    xs = [slot[d] for d in pos.index]
    ys = pos.values
    
    # bubbles + text
    plt.scatter(xs, ys, s=200, alpha=0.8)
    for d, x, y in zip(pos.index, xs, ys):
        plt.text(x, y, d[:3], ha="center", va="center", color="white")
    
    plt.gca().invert_yaxis()
    plt.xticks(list(slot.values()), drivers, rotation=90)
    plt.ylabel("Position")
    plt.title(f"Lap {lap}")
    plt.tight_layout()
    plt.show()
    

# 4) interactive slider
interact(plot_lap, lap=(1, wide.shape[1], 1))
# Out:
# <function __main__.plot_lap(lap: int)>

# %%
slot
# Out:
# {'VAN': 1,
#  'RIC': 2,
#  'VET': 3,
#  'RAI': 4,
#  'GRO': 5,
#  'ERI': 6,
#  'GAS': 7,
#  'PER': 8,
#  'ALO': 9,
#  'LEC': 10,
#  'STR': 11,
#  'MAG': 12,
#  'HUL': 13,
#  'HAR': 14,
#  'OCO': 15,
#  'VER': 16,
#  'SIR': 17,
#  'HAM': 18,
#  'SAI': 19,
#  'BOT': 20}
